# %% [markdown]
# # Imports

# %%
import sqlite3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Functions

# %%
def tables(link:str):
  file = pd.ExcelFile(link)
  sheets = file.sheet_names
  table_list = []
  for name in sheets:
    x = pd.read_excel(link,sheet_name=name)
    if 'Unnamed: 0' in x.columns:
      x = x.drop('Unnamed: 0',axis=1)
    table_list.append(x)
  return table_list

# %%
def saving_sql(experiment:str,sheets_names,tables:list,index):
  table_name = experiment+f'_{sheets_names[index]}'
  table = tables[index]
  table.to_sql(table_name,conn,if_exists='replace',index=False)

# %% [markdown]
# # Daten

# %% [markdown]
# ## F4

# %%
f4 = 'https://github.com/Ben-physics-dotcom/Internships/raw/refs/heads/main/GPR1/Data/F4-Federkonstante.xlsx'
f4_sheets = pd.ExcelFile(f4)
print(f4_sheets.sheet_names)
# Out:
# ['Aufgabe-1', 'Aufgabe-2', 'Aufgabe-3']

# %%
f4_tables = []
for name in f4_sheets.sheet_names:
  x = pd.read_excel(f4,sheet_name=name)
  x = x.drop('Unnamed: 0',axis=1)
  f4_tables.append(x)

# %% [markdown]
# ### F4 Controll

# %%
a1_f4 = pd.read_excel(f4,sheet_name=f4_sheets.sheet_names[0])
a1_f4.head()
# Out:
#    Unnamed: 0  Masse [g]  Auslenkung [cm]  Masse 1 [g]  Auslenkung 1 [cm]  \
# 0           0          0            19.65          400              11.15
# 1           1         50            18.50          350              12.30
# 2           2        100            17.35          300              13.35
# 3           3        150            16.40          250              14.45
# 4           4        200            15.30          200              15.50
#
#    Massen n  Masse [g] Unsicherheit: 0.005g
# 0       1.0                          49.995
# 1       2.0                          50.261
# 2       3.0                          50.656
# 3       4.0                          50.418
# 4       5.0                          49.970

# %%
a1_f4 = a1_f4.drop('Unnamed: 0',axis=1)
a1_f4.tail()
# Out:
#    Masse [g]  Auslenkung [cm]  Masse 1 [g]  Auslenkung 1 [cm]  Massen n  \
# 4        200            15.30          200              15.50       5.0
# 5        250            14.25          150              16.65       6.0
# 6        300            13.15          100              17.45       7.0
# 7        350            12.05           50              18.75       8.0
# 8        400            11.10            0              19.80       NaN
#
#    Masse [g] Unsicherheit: 0.005g
# 4                          49.970
# 5                          49.930
# 6                          50.210
# 7                          50.824
# 8                             NaN

# %%
a2_f4 = pd.read_excel(f4,sheet_name=f4_sheets.sheet_names[1])
a2_f4.head()
# Out:
#    Unnamed: 0  n  Schwingungen  T [s]  Masse [g]
# 0           0  1            19  10.85        400
# 1           1  2            19  10.78        400
# 2           2  3            20  11.47        400
# 3           3  4            20  11.37        400
# 4           4  5            20  11.16        350

# %%
a2_f4 = a2_f4.drop('Unnamed: 0',axis=1)
a2_f4.tail()
# Out:
#      n  Schwingungen  T [s]  Masse [g]
# 8    9            20  10.59        300
# 9   10            20   9.91        300
# 10  11            20  10.44        300
# 11  12            20  10.00        250
# 12  13            20   9.93        250

# %%
a3_f4 = pd.read_excel(f4,sheet_name=f4_sheets.sheet_names[2])
a3_f4.head()
# Out:
#    Unnamed: 0     Variablenname Formelzeichen     Wert  Unsicherheit  Einheit
# 0           0     Torsionsmodel             G    8.100         0.700  10^10Pa
# 1           1        Drahtlänge             l  661.000         5.000       mm
# 2           2  Drahtdurchmesser             d    0.805         0.003        m
# 3           3      Wickelradius             r   10.500         0.200        m

# %%
a3_f4 = a3_f4.drop('Unnamed: 0',axis=1)
a3_f4.tail()
# Out:
#       Variablenname Formelzeichen     Wert  Unsicherheit  Einheit
# 0     Torsionsmodel             G    8.100         0.700  10^10Pa
# 1        Drahtlänge             l  661.000         5.000       mm
# 2  Drahtdurchmesser             d    0.805         0.003        m
# 3      Wickelradius             r   10.500         0.200        m

# %% [markdown]
# ## M10

# %%
m10 = 'https://github.com/Ben-physics-dotcom/Internships/raw/refs/heads/main/GPR1/Data/M10.xlsx'
m10s = pd.ExcelFile(m10)
print(m10s.sheet_names)
# Out:
# ['Aufgabe-1', 'Aufgabe-3', 'Aufgabe-2']

# %%
m10_tables = tables(m10)
m10_tables[0]
# Out:
#    Kreisdrehzahl: n [s^-1]  Masse [kg]  Periodendauer T_p [s]  Perioden p
# 0                    10.81        0.05                  12.98           1
# 1                    10.70        0.10                   6.49           1
# 2                    10.70        0.15                   4.49           1
# 3                    10.70        0.20                   3.49           1
# 4                    10.75        0.25                   8.38           3
# 5                    10.80        0.30                   7.75           3
# 6                    10.80        0.35                   6.74           3
# 7                    10.80        0.40                   7.55           3
# 8                    10.80        0.45                   6.91           4
# 9                    10.80        0.50                   5.71           4

# %% [markdown]
# ## M12

# %%
m12 = 'https://github.com/Ben-physics-dotcom/Internships/raw/refs/heads/main/GPR1/Data/M12-Saitenschwinung.xlsx'
m12s = pd.ExcelFile(m12)
print(m12s.sheet_names)
# Out:
# ['Resonanzmessung', 'MR_2_MR_3']

# %%
m12_tables = tables(m12)

# %% [markdown]
# ## M2

# %%
m2 = 'https://github.com/Ben-physics-dotcom/Internships/raw/refs/heads/main/GPR1/Data/M2-Tr%C3%A4gheitsmoment.xlsx'
m2s = pd.ExcelFile(m2)
print(m2s.sheet_names)
# Out:
# ['Scheibe', 'Zylinder']

# %%
m2_tables = tables(m2)

# %% [markdown]
# ## M3

# %%
m3 = 'https://github.com/Ben-physics-dotcom/Internships/raw/refs/heads/main/GPR1/Data/M3.xlsx'
m3s = pd.ExcelFile(m3)
print(m3s.sheet_names)
# Out:
# ['Aufgabe-1', 'Aufgabe-3', 'Abnahme A1', 'Unsicherheit-50g+Scheibe']

# %%
m3_tables = tables(m3)

# %% [markdown]
# ## M5

# %%
m5 = 'https://github.com/Ben-physics-dotcom/Internships/raw/refs/heads/main/GPR1/Data/M5.xlsx'
m5s = pd.ExcelFile(m5)
print(m5s.sheet_names)
# Out:
# ['Aufgabe-1', 'Infos']

# %%
m5_tables = tables(m5)

# %% [markdown]
# ## T1

# %%
t1 = 'https://github.com/Ben-physics-dotcom/Internships/raw/refs/heads/main/GPR1/Data/T1-W%C3%A4rmekapazit%C3%A4t-eines-Kalorimeters.xlsx'
t1s = pd.ExcelFile(t1)
print(t1s.sheet_names)
# Out:
# ['Aufgabe-1', 'Aufgabe-3', 'Unsicherheiten']

# %%
t1_tables = tables(t1)

# %% [markdown]
# ## T7

# %%
t7 = 'https://github.com/Ben-physics-dotcom/Internships/raw/refs/heads/main/GPR1/Data/T7-Spezifische-W%C3%A4rmemenge.xlsx'
t7s = pd.ExcelFile(t7)
print(t7s.sheet_names)
# Out:
# ['Adiabatischexponent', 'A2-und-A3']

# %%
t7_tables = tables(t7)

# %% [markdown]
# # Database

# %%
conn = sqlite3.connect('GPR1.db')
c = conn.cursor()

# %%
c.execute('''
CREATE TABLE IF NOT EXISTS gpr1_overview (
  Experiment TEXT PRIMARY KEY,
  Notebook TEXT,
  Number_of_Tables INT
)
 ''')

# %%
c.execute(
    '''
    INSERT INTO gpr1_overview (Experiment, Notebook, Number_of_Tables) VALUES
    ('T7','https://raw.githubusercontent.com/Ben-physics-dotcom/Internships/refs/heads/main/GPR1/T7/T7_Spezifische_W%C3%A4rmekapazit%C3%A4t.ipynb','2'),
    ('M12','https://raw.githubusercontent.com/Ben-physics-dotcom/Internships/refs/heads/main/GPR1/M12/M12.ipynb','2'),
    ('F4','https://raw.githubusercontent.com/Ben-physics-dotcom/Internships/refs/heads/main/GPR1/F4-Federkonstante/F4_Federkonstante.ipynb','3'),
    ('T1','https://raw.githubusercontent.com/Ben-physics-dotcom/Internships/refs/heads/main/GPR1/T1_W%C3%A4rmekapazit%C3%A4t_eines_Kalorimeters.ipynb','3')
    '''
)

# %%
type(f4_tables[0])
# Out:
# pandas.core.frame.DataFrame

# %%
for i in range(3):
  # 4
  saving_sql('F4',f4_sheets.sheet_names,f4_tables,i)
  # T1
  saving_sql('T1',t1s.sheet_names,t1_tables,i)

# %%
for i in range(2):
  saving_sql('M12',m12s.sheet_names,m12_tables,i)
  saving_sql('M2',m2s.sheet_names,m2_tables,i)
  saving_sql('M5',m5s.sheet_names,m5_tables,i)
  saving_sql('T7',t7s.sheet_names,t7_tables,i)

# %%
for i in range(4):
  saving_sql('M3',m3s.sheet_names,m3_tables,i)

# %%
# Query to list all tables in the database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Print all table names
print("Tables in the database:")
for table in tables:
    print(table[0])
# Out:
# Tables in the database:
# gpr1_overview
# F4_Aufgabe-1
# T1_Aufgabe-1
# F4_Aufgabe-2
# T1_Aufgabe-3
# F4_Aufgabe-3
# T1_Unsicherheiten
# M12_Resonanzmessung
# M2_Scheibe
# M5_Aufgabe-1
# T7_Adiabatischexponent
# M12_MR_2_MR_3
# M2_Zylinder
# M5_Infos
# T7_A2-und-A3
# M3_Aufgabe-1
# M3_Aufgabe-3
# M3_Abnahme A1
# M3_Unsicherheit-50g+Scheibe

# %%
conn.commit()
c.execute('SELECT * FROM gpr1_overview')
rows = c.fetchall()

for row in rows:
  print(row)

conn.close()
# Out:
# ('T7', 'https://raw.githubusercontent.com/Ben-physics-dotcom/Internships/refs/heads/main/GPR1/T7/T7_Spezifische_W%C3%A4rmekapazit%C3%A4t.ipynb', 2)
# ('M12', 'https://raw.githubusercontent.com/Ben-physics-dotcom/Internships/refs/heads/main/GPR1/M12/M12.ipynb', 2)
# ('F4', 'https://raw.githubusercontent.com/Ben-physics-dotcom/Internships/refs/heads/main/GPR1/F4-Federkonstante/F4_Federkonstante.ipynb', 3)
# ('T1', 'https://raw.githubusercontent.com/Ben-physics-dotcom/Internships/refs/heads/main/GPR1/T1_W%C3%A4rmekapazit%C3%A4t_eines_Kalorimeters.ipynb', 3)
